# %%
import csv
import random
import sched, time, threading
import string
from Read import getUser, getMessage
from Socket import openSocket, sendMessage
from Initialize import joinRoom

# %%
all_quiz=[]
user_point_dict={}
current_quiz_id=None
current_quiz_answer=''
current_question_ended=False
quiz_running = False
s = openSocket()
joinRoom(s)
readbuffer = ""
i=1


def init_quiz():
    global all_quiz
    quiz_running = True
    with open('quiz.csv', 'r') as f:
        reader = csv.reader(f)
        all_quiz = list(reader)


def reinit_globals():
    global user_point_dict, current_quiz_answer
    user_point_dict = {}
    current_quiz_answer = ''
# Out:
# :tmi.twitch.tv 001 chesstriviabot :Welcome, GLHF!
# :tmi.twitch.tv 002 chesstriviabot :Your host is tmi.twitch.tv
# :tmi.twitch.tv 003 chesstriviabot :This server is rather new
# :tmi.twitch.tv 004 chesstriviabot :-
# :tmi.twitch.tv 375 chesstriviabot :-
# :tmi.twitch.tv 372 chesstriviabot :You are in a maze of twisty passages, all alike.
# :tmi.twitch.tv 376 chesstriviabot :>
# :chesstriviabot!chesstriviabot@chesstriviabot.tmi.twitch.tv JOIN #conmonbon
# :chesstriviabot.tmi.twitch.tv 353 chesstriviabot = #conmonbon :chesstriviabot
# :chesstriviabot.tmi.twitch.tv 366 chesstriviabot #conmonbon :End of /NAMES list
# Sent: PRIVMSG #conmonbon :Successfully joined chat

# %%
def get_random_quiz():
    if len(all_quiz)<1:
        return None
    l= random.choice(all_quiz)
    all_quiz.remove(l)
    return l

# %%
def make_quiz_question(l):
    global current_quiz_answer
    global current_question_ended
    current_question_ended = False
    q = l[1]
    s= l[0]+" 1. {0}  2. {1} 3. {2}. 4. {3}".format(l[1],l[2],l[3],l[4])
    global current_quiz_answer
    current_quiz_answer = l[5]
    return s


def print_question():
    print make_quiz_question(val)
    



def thread_entry():
    global quiz_running
    global s
    sendMessage(s,'Starting Chess Triva in 5 seconds. Hold your Horses and Pawns')
    time.sleep(5)
    while quiz_running:
        q = get_random_quiz()
        ##if no questin left
        if q is None:
            quiz_running = False
        else:
            sendMessage(s, make_quiz_question(q) )
            
            time.sleep(30)

            
        



def send_top():
    global user_point_dict
    global s
    st=''
    counter=0
    #print if not empty
    if user_point_dict :
        keys=key=sorted(user_point_dict, key=user_point_dict.get, reverse=True)
        for i in keys:
            counter += 1
            st= st+ str( counter)+'. ' + i + '('+ str(user_point_dict[i]) + ')  '
            if counter == 5:
                break
                
    sendMessage(s,st)
   
        
        
        
    

##check commands
def user_is_mod(user):
    return True



##check commands
def check_command(chat, user):
    global quiz_running
    global current_quiz_answer
    global current_question_ended
    global s
    print 'checking command: ', chat
    print 'right answer: ', current_quiz_answer
    
    if '!startQuiz' in chat:
        if user_is_mod(user):
            if quiz_running == False:
                init_quiz()
                quiz_running = True
                t=threading.Thread(target=thread_entry)
                t.setDaemon(True)
                t.start()
                print "Thread started"
    if '!stopQuiz' in chat:
        quiz_running = False
        reinit_globals()
        
    if '!top5' in chat:
        print 'Sending top'
        send_top()
    
    if quiz_running and not current_question_ended and current_quiz_answer and current_quiz_answer.lower() in chat.lower():
        ms = 'Correct answer by: ' + user
        current_question_ended = True
        sendMessage(s,ms)
        if user_point_dict.has_key(user):
            user_point_dict[user] = user_point_dict[user]+1
        else:
            user_point_dict[user] = 1
        
            
    

#check_command('!startQuizfsd', 'test')

# %%
while True:
        readbuffer = readbuffer + s.recv(1024)
        temp = string.split(readbuffer, "\n")
        readbuffer = temp.pop()
        i=i+1
        print i, len(temp), temp

        for line in temp:
                        
            if "PING" in line:
                s.send(line.replace("PING", "PONG") + "\r\n")
                break

            user = getUser(line)
            message = getMessage(line)
            check_command(message, user)
# Out:
# 2 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :!startQuiz\r']
# checking command:  !startQuiz
# right answer: Sent: PRIVMSG #conmonbon :Starting Chess Triva in 5 seconds. Hold your Horses
#
# Thread started
# 3 1 [':nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #conmonbon :Subscribe free this channel using Amazon Prime https://twitch.amazon.com/prime\r']
# checking command:  Subscribe free this channel using Amazon Prime https://twitch.amazon.com/prime
# right answer:
# Sent: PRIVMSG #conmonbon :Which actor played chess frequently? 1. John wayne  2. Johnny Depp 3. Tom Cruise. 4. Di Caprio
# 4 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :John wayne\r']
# checking command:  John wayne
# right answer:  John wayne
# Sent: PRIVMSG #conmonbon :Correct answer by: conmonbon
# 5 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :John wayne\r']
# checking command:  John wayne
# right answer:  John wayne
# 6 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :!top5\r']
# checking command:  !top5
# right answer:  John wayne
# Sending top
# Sent: PRIVMSG #conmonbon :1. conmonbon(1)
# Sent: PRIVMSG #conmonbon :Where did Jose Raul Capablanca die? 1. USA  2. Portugal 3. Spain. 4. Mexico
# 7 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :protugal\r']
# checking command:  protugal
# right answer:  USA
# 8 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :portugal\r']
# checking command:  portugal
# right answer:  USA
# 9 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :usa\r']
# checking command:  usa
# right answer:  USA
# Sent: PRIVMSG #conmonbon :Correct answer by: conmonbon
# Sent: PRIVMSG #conmonbon :1.d4 Nf6 2.c4 e6 3.Nc3 Bb4  whats the name of this defense? 1. Indian Ninja  2. Nimzo-Indian 3. Budapest. 4. Bang bang
# 10 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :Nimzo-indian\r']
# checking command:  Nimzo-indian
# right answer:  Nimzo-indian
# Sent: PRIVMSG #conmonbon :Correct answer by: conmonbon
# Sent: PRIVMSG #conmonbon :Where is Magnus Carlsen from? 1. Portugal  2. USA 3. Sweden. 4. Norway
# 11 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :portugal\r']
# checking command:  portugal
# right answer:  Norway
# 12 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :norway\r']
# checking command:  norway
# right answer:  Norway
# Sent: PRIVMSG #conmonbon :Correct answer by: conmonbon
# Sent: PRIVMSG #conmonbon :Which year was Pawn moves 2 squares introduced i? 1. 680  2. 1200 3. 1280. 4. 1920
# 13 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :1920\r']
# checking command:  1920
# right answer:  1280
# 14 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :1280\r']
# checking command:  1280
# right answer:  1280
# Sent: PRIVMSG #conmonbon :Correct answer by: conmonbon
# 15 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :!stopQuiz\r']
# checking command:  !stopQuiz
# right answer:  1280
# 16 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :!startQuiz\r']
# checking command:  !startQuiz
# right answer:
# Thread started
# Sent: PRIVMSG #conmonbon :Starting Chess Triva in 5 seconds. Hold your Horses
# Sent: PRIVMSG #conmonbon :Where is Magnus Carlsen from? 1. Portugal  2. USA 3. Sweden. 4. Norway
# Sent: PRIVMSG #conmonbon :First game played between earth and space? 1. Apollo5  2. Apollo11 3. Soyuz 9. 4. Mars Rover
# 17 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :!norway\r']
# checking command:  !norway
# right answer:  Soyuz 9
# 18 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :soyuz 9\r']
# checking command:  soyuz 9
# right answer:  Soyuz 9
# Sent: PRIVMSG #conmonbon :Correct answer by: conmonbon
# Sent: PRIVMSG #conmonbon :1.d4 Nf6 2.c4 e6 3.Nc3 Bb4  whats the name of this defense? 1. Indian Ninja  2. Nimzo-Indian 3. Budapest. 4. Bang bang
# Sent: PRIVMSG #conmonbon :Which year was Pawn moves 2 squares introduced i? 1. 680  2. 1200 3. 1280. 4. 1920
# Sent: PRIVMSG #conmonbon :Which actor played chess frequently? 1. John wayne  2. Johnny Depp 3. Tom Cruise. 4. Di Caprio
# Sent: PRIVMSG #conmonbon :Where did Jose Raul Capablanca die? 1. USA  2. Portugal 3. Spain. 4. Mexico
# 19 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :!stopQuiz\r']
# checking command:  !stopQuiz
# right answer:  USA
# 20 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :!startQuiz\r']
# checking command:  !startQuiz
#  right answer: Sent: PRIVMSG #conmonbon :Starting Chess Triva in 5 seconds. Hold your Horses
#
# Thread started
# Sent: PRIVMSG #conmonbon :Which year was Pawn moves 2 squares introduced i? 1. 680  2. 1200 3. 1280. 4. 1920
# 21 1 ['PING :tmi.twitch.tv\r']
# 22 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :1920\r']
# checking command:  1920
# right answer:  1280
# Sent: PRIVMSG #conmonbon :1.d4 Nf6 2.c4 c5 3.d5 e6 Name of this defense? 1. Modern Benoni  2. French  3. Berlin. 4. Hodor Defense
# 23 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :!top5\r']
# checking command:  !top5
# right answer:  Modern Benoni
# Sending top
# Sent: PRIVMSG #conmonbon :
# Sent: PRIVMSG #conmonbon :Origin of Chess? 1. Persia  2. Republic of Wadiya 3. India. 4. USA
# 24 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :india\r']
# checking command:  india
# right answer:  India
# Sent: PRIVMSG #conmonbon :Correct answer by: conmonbon
# Sent: PRIVMSG #conmonbon :Where was Judith Polgar born? 1. Germany  2. USA 3. Hungary. 4. Switzerland
# Sent: PRIVMSG #conmonbon :Which world champion was defeated by Bobby Fisher most recently? 1. Karparov  2. Kasparov 3. Spassky. 4. Magnus Carlsen
# Sent: PRIVMSG #conmonbon :Which movie has a chess game in it? 1. The PatzerInception  2.  3. A Game of Shodows. 4. Mate at the Gate
# Sent: PRIVMSG #conmonbon :who plays in the movie Game Over? 1. Bobby Fischer  2. Karparov 3. Kasparov. 4. Eric Hansen
# Sent: PRIVMSG #conmonbon :1.d4 Nf6 2.c4 e6 3.Nc3 Bb4  whats the name of this defense? 1. Indian Ninja  2. Nimzo-Indian 3. Budapest. 4. Bang bang
# Sent: PRIVMSG #conmonbon :How many possibilities at the very first move? 1. 10  2. 20 3. 30. 4. 40
# Sent: PRIVMSG #conmonbon :Where was Mikhail Tal born? 1. Georgia  2. Armenia 3. Russia. 4. Latvia
# 25 1 ['PING :tmi.twitch.tv\r']
# Sent: PRIVMSG #conmonbon :Where did Jose Raul Capablanca die? 1. USA  2. Portugal 3. Spain. 4. Mexico
# 26 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :usa\r']
# checking command:  usa
# right answer:  USA
# Sent: PRIVMSG #conmonbon :Correct answer by: conmonbon
# 27 1 [':conmonbon!conmonbon@conmonbon.tmi.twitch.tv PRIVMSG #conmonbon :!top5\r']
# checking command:  !top5
# right answer:  USA
# Sending top
# Sent: PRIVMSG #conmonbon :1. conmonbon(2)
# Sent: PRIVMSG #conmonbon :Where is Magnus Carlsen from? 1. Portugal  2. USA 3. Sweden. 4. Norway
# 28 1 [':nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #conmonbon :Subscribe free this channel using Amazon Prime https://twitch.amazon.com/prime\r']
# checking command:  Subscribe free this channel using Amazon Prime https://twitch.amazon.com/prime
# right answer:  Norway
# Sent: PRIVMSG #conmonbon :First game played between earth and space? 1. Apollo5  2. Apollo11 3. Soyuz 9. 4. Mars Rover
# Sent: PRIVMSG #conmonbon :what was kasparov’s last name before it was changed 1. Weinstein  2. Einstein 3. Dreistein. 4. Achtstein
# Sent: PRIVMSG #conmonbon :what does “en passant” mean? 1. In passing  2. pass or burn 3. pass in Fuss. 4. passing by
# Sent: PRIVMSG #conmonbon :Meaniing of Pawn in german? 1. Culprit  2. King 3. Peasant. 4. Soldier
# Sent: PRIVMSG #conmonbon :Which actor played chess frequently? 1. John wayne  2. Johnny Depp 3. Tom Cruise. 4. Di Caprio
# 29 1 ['PING :tmi.twitch.tv\r']
# 30 1 ['PING :tmi.twitch.tv\r']
# 31 1 ['PING :tmi.twitch.tv\r']
# 32 1 ['PING :tmi.twitch.tv\r']
# 33 1 ['PING :tmi.twitch.tv\r']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-6735aa929fd7> in <module>()
#       1 while True:
# ----> 2         readbuffer = readbuffer + s.recv(1024)
#       3         temp = string.split(readbuffer, "\n")
#       4         readbuffer = temp.pop()
#       5         i=i+1
#
# KeyboardInterrupt:
